# %%
class Human:
    def __init__(self, name, age):
       self.name = name
       self.age = age

    def printinfo(self):
      print(self.name)
      print(self.age)

hanako = Human("花子", 36)

hanako.printinfo()
# Out:
# 花子
# 36
